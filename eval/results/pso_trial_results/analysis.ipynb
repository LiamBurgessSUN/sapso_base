# %%
from df_utils import scale_range

# %%
from df_utils import group_by_stats

# Corrected Aggregation: Remove the double brackets selection to include all columns

# %%
# Given your previously defined 'runs = df.groupby(["run"])'

# %%
del aggregate
del df
